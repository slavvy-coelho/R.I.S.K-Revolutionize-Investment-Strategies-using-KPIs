# %% [markdown]
# # Web Scraping: Daily Mail

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re
import time

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# url definition
url = "https://www.dailymail.co.uk"

# Request
r1 = requests.get(url)
r1.status_code

# We'll save in coverpage the cover page content
coverpage = r1.content

# Soup creation
soup1 = BeautifulSoup(coverpage, 'html5lib')

# News identification
coverpage_news = soup1.find_all('h2', class_='linkro-darkred')
len(coverpage_news)
# Out:
# 189

# %% [markdown]
# ## Let's extract the text from the articles

# %%
number_of_articles = len(coverpage_news)

# Empty lists for content, links and titles
news_contents = []
list_links = []
list_titles = []

for n in np.arange(0, number_of_articles):
        
    # Getting the link of the article
    link = url + coverpage_news[n].find('a')['href']
    list_links.append(link)
    
    # Getting the title
    title = coverpage_news[n].find('a').get_text()
    list_titles.append(title)
    
    # Reading the content (it is divided in paragraphs)
    article = requests.get(link)
    article_content = article.content
    soup_article = BeautifulSoup(article_content, 'html5lib')
    body = soup_article.find_all('p', class_='mol-para-with-font')
    
    # Unifying the paragraphs
    list_paragraphs = []
    for p in np.arange(0, len(body)):
        paragraph = body[p].get_text()
        list_paragraphs.append(paragraph)
        final_article = " ".join(list_paragraphs)
        
    # Removing special characters
    final_article = re.sub("\\xa0", "", final_article)
        
    news_contents.append(final_article)

# %% [markdown]
# Let's put them into:
#
# 1. a dataset which will the input of the models (df_features)
# 2. a dataset with the title and the link (df_show_info)

# %%
# df_features
df_features = pd.DataFrame(
     {'Article Content': news_contents 
    })

# df_show_info
df_show_info = pd.DataFrame(
    {'Article Title': list_titles,
     'Article Link': list_links})

# %%
df_features
# Out:
#                                        Article Content
# 0    The number of coronavirus infections in South ...
# 1    The United States death toll from the coronavi...
# 2    Furious demonstrators gathered Wednesday at Mi...
# 3    In early April, the CDC recommended that all A...
# 4    A pair of scientists believe that up to 270,00...
# 5    The Internal Revenue Service's online tool tha...
# 6    A crash federal government lending program mea...
# 7    A Michigan doctor has claimed he will prove wh...
# 8    Two Democratic congressmen have proposed expan...
# 9    The director of the Centers for Disease Contro...
# 10   Numerous major U.S. airlines are preparing to ...
# 11   The World Heath Organisation has found itself ...
# 12   Nancy Pelosi railed against Donald Trump in a ...
# 13   Three whistle-blowers who tried to inform the ...
# 14   The Pentagon's inspector general on Wednesday ...
# 15   When world-famous artist David Hockney wrote a...
# 16   1) How essential is the business? Cuomo did no...
# 17   House Speaker Nancy Pelosi called President Tr...
# 18   New York state has only received about $12,000...
# 19   An upscale outlet mall near Omaha, Nebraska, i...
# 20   A government watchdog agency has ruled that th...
# 21   Former President Barack Obama reportedly playe...
# 22   Rep. Alexandria Ocasio-Cortez said Wednesday'i...
# 23   Bill Gates slammed President Donald Trump’s de...
# 24   The head of the World Health Organization said...
# 25   The first results from an international experi...
# 26   Franklin Graham, the evangelical pastor whose ...
# 27   Kellyanne Conway, during an appearance on Fox ...
# 28   President Donald Trump's new expansive list of...
# 29   Dr Anthony Fauci has stopped short of naming a...
# ..                                                 ...
# 159  Incredible high-definition snaps show the Inte...
# 160  A team of retirees that scours the remote ravi...
# 161  A couple has recreated famous movie scenes usi...
# 162  These incredible images capture the South Suda...
# 163  Experts believe they have discovered a remnant...
# 164  Credentials belonging to more than 500,000 Zoo...
# 165  Instead of standing out from the crowd, this n...
# 166  Astronauts rely on highly-engineered and sophi...
# 167  Studying flying reptiles called pterosaurs tha...
# 168  This is the disturbing moment a group of hitme...
# 169  A pride of 22 lions stopped a game ranger in h...
# 170  Mike Tyson's friend and former trainer Jeff Fe...
# 171  Former Real Housewives of Orange County star K...
# 172  A woman has recreated her own McDonald’s Mocha...
# 173  A truck driver has been rescued from his cab a...
# 174  From cross-stitching to backgammon, these mill...
# 175  Scientists working from home due to coronaviru...
# 176  A Floridafather killed his two children before...
# 177  Spending months in space without gravity can c...
# 178  A photographer has captured a rare glimpse int...
# 179  This tricky maze challenges you to work out wh...
# 180  Saudi Arabia has doubled its use of the death ...
# 181  An adventurous baby boy can't help but giggle ...
# 182  The Swiss property where Mary Shelley wrote he...
# 183  A British Airways jet crashed into an Emirates...
# 184  Behold the breathtaking winning and shortliste...
# 185  The ancient creators of Stonehenge built the m...
# 186  Natalie Wood is the subject of a new HBO docum...
# 187  While kids of today log onto the internet and ...
# 188  A herd of adult and baby wild elephants stoppe...
#
# [189 rows x 1 columns]

# %%
df_show_info
# Out:
#                                          Article Title  \
# 0    South Dakota's Republican governor Kristi Noem...
# 1    Death toll in the US nears 30,000 after 1,500 ...
# 2    Protesters flood the streets and block traffic...
# 3    What face mask should YOU choose? As several s...
# 4    California has 10 times more coronavirus cases...
# 5    Chaos over $1,200 stimulus checks: IRS trackin...
# 6    $350 billion paycheck protection program is 'o...
# 7    Michigan doctor claims he will prove how long ...
# 8    Two Democratic congressman propose $2,000-a-mo...
# 9    Trump's CDC director contradicts him over WHO ...
# 10   Major U.S. airlines plan to apply for billions...
# 11   No human-to-human transmission, no travel bans...
# 12   Pelosi unloads on Trump calling him a 'weak pe...
# 13   Where are they, President Xi?Three coronavirus...
# 14   White House gagged officials from saying wheth...
# 15   Does smoking PROTECT against coronavirus? That...
# 16   New Yorkers MUST now wear face masks in public...
# 17   Nancy Pelosi calls Donald Trump's freeze on WH...
# 18   Hard-hit New York to receive $12k in federal f...
# 19   Nebraska outlet mall plans to reopen in NINE D...
# 20   Government watchdog found NO evidence of White...
# 21   REVEALED: Obama 'convinced Bernie Sanders to d...
# 22   AOC tells The View 'inequality is a pre-existi...
# 23   Bill Gates says Trump is 'dangerous' for cutti...
# 24   WHO chief says he 'regrets' Donald Trump's dec...
# 25   Experimental coronavirus treatment Remsvidir i...
# 26   Pastor Franklin Graham says he's being harasse...
# 27   'This is Covid-19 not Covid-1 folks!' Kellyann...
# 28   Trump prepares for day of talks with his 'reop...
# 29   Dr Fauci REFUSES to name one state that could ...
# ..                                                 ...
# 159  International Space Station appears as a tiny ...
# 160  FBI agent discovers 10 pioneer-era apples in W...
# 161  Who needs the cinema? Film buff couple recreat...
# 162  The tribe who worship cows and treat them as e...
# 163  Mysterious exoplanet 40 times bigger than Eart...
# 164  More than 500,000 Zoom user credentials have b...
# 165  Now you see it... The cunningly camouflaged su...
# 166  ESA reveals a concept space glove for future a...
# 167  Learning more about pterosaurs, flying reptile...
# 168  Terrifying moment hitmen crash their car into ...
# 169  Unnerving moment a pride of lions surrounds ga...
# 170  'I certainly had to change the undies that day...
# 171  RHOC star Kara Keough reveals her son McCoy di...
# 172  Woman reveals how to create your own McDonald'...
# 173  Dramatic moment truck driver is rescued from h...
# 174  Rise of the middle-aged millennials! From cros...
# 175  NASA takes 'working from home' to new heights:...
# 176  Florida father shoots dead his son, 13, and da...
# 177  Astronauts who spend more than six months in s...
# 178  Lives of London's Irish Gypsys revealed: Photo...
# 179  Tricky maze challenges you to work out which o...
# 180  Saudi Arabia has doubled its use of the death ...
# 181  Shutter happiness: Adorable baby boy can't sto...
# 182  A real house of horror! Swiss property beside ...
# 183  British Airways Airbus crashes into an Emirate...
# 184  Enchanting forests, dramatic waves and magical...
# 185  Prehistoric Lego! Aerial images show that anci...
